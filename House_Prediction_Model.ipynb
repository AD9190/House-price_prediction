# %% [markdown]
# <a href="https://colab.research.google.com/github/AD9190/House-price_prediction/blob/main/House_Prediction_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
X= data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
train_data=X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8544     -118.36     33.88                22.0       1388.0           336.0
# 3244     -119.57     36.10                36.0       1729.0           317.0
# 15232    -117.21     33.02                26.0       3194.0           454.0
# 2221     -119.84     36.82                17.0       2807.0           376.0
# 8796     -118.41     33.77                22.0       7554.0           991.0
# ...          ...       ...                 ...          ...             ...
# 19452    -120.94     37.68                 4.0      13315.0          2424.0
# 5635     -118.28     33.75                21.0       2442.0           719.0
# 2125     -119.71     36.79                34.0       1891.0           323.0
# 14411    -117.23     32.79                28.0       2453.0           648.0
# 11384    -117.95     33.66                26.0       1787.0           227.0
#
# ...

# %%
train_data.hist(figsize=(15,7))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,7.5))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <ipython-input-144-fbad6caea978>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# <Axes: >

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,7.5))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8544     -118.36     33.88                22.0     7.236339        5.820083
# 3244     -119.57     36.10                36.0     7.455877        5.762051
# 15232    -117.21     33.02                26.0     8.069342        6.120297
# 2221     -119.84     36.82                17.0     7.940228        5.932245
# 8796     -118.41     33.77                22.0     8.929965        6.899723
# ...          ...       ...                 ...          ...             ...
# 19452    -120.94     37.68                 4.0     9.496722        7.793587
# 5635     -118.28     33.75                21.0     7.800982        6.579251
# 2125     -119.71     36.79                34.0     7.545390        5.780744
# 14411    -117.23     32.79                28.0     7.805475        6.475433
# 11384    -117.95     33.66                26.0     7.488853        5.429346
#
# ...

# %%
train_data.hist(figsize=(15,7.5))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>,
#         <Axes: title={'center': 'total_rooms'}>],
#        [<Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>],
#        [<Axes: title={'center': 'median_house_value'}>,
#         <Axes: title={'center': '<1H OCEAN'}>,
#         <Axes: title={'center': 'INLAND'}>,
#         <Axes: title={'center': 'ISLAND'}>],
#        [<Axes: title={'center': 'NEAR BAY'}>,
#         <Axes: title={'center': 'NEAR OCEAN'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(15,7.5))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,7.5))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize=(15,7.5))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
plt.figure(figsize=(15,7.5))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8544     -118.36     33.88                22.0     7.236339        5.820083
# 3244     -119.57     36.10                36.0     7.455877        5.762051
# 15232    -117.21     33.02                26.0     8.069342        6.120297
# 2221     -119.84     36.82                17.0     7.940228        5.932245
# 8796     -118.41     33.77                22.0     8.929965        6.899723
# ...          ...       ...                 ...          ...             ...
# 19452    -120.94     37.68                 4.0     9.496722        7.793587
# 5635     -118.28     33.75                21.0     7.800982        6.579251
# 2125     -119.71     36.79                34.0     7.545390        5.780744
# 14411    -117.23     32.79                28.0     7.805475        6.475433
# 11384    -117.95     33.66                26.0     7.488853        5.429346
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
X_train_s=scaler.fit_transform(X_train)

# %%
reg.fit(X_train_s,y_train)
# Out:
# LinearRegression()

# %%
test_data=X_test.join(y_test)

test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)


test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']

# %%
X_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4028     -118.56     34.18                39.0     7.506592        5.676754
# 17392    -120.45     34.96                21.0     7.660114        6.100319
# 11731    -120.81     39.02                30.0     6.693324        5.247024
# 12421    -116.23     33.72                32.0     8.513587        7.190676
# 1632     -122.17     37.87                38.0     7.140453        5.181784
# ...          ...       ...                 ...          ...             ...
# 12531    -121.50     38.57                44.0     7.226936        5.863631
# 13120    -121.27     38.31                17.0     7.043160        5.313206
# 20330    -119.03     34.25                25.0     8.115222        6.220590
# 6473     -118.07     34.09                40.0     7.465083        5.916202
# 887      -121.99     37.55                16.0     8.802071        7.649216
#
# ...

# %%
test_data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity', 'median_house_value', 'bedroom_ratio',
#        'household_rooms'],
#       dtype='object')

# %%
test_data.rename(columns={'ocean_proximity': 'ocean'}, inplace=True)

# %%
test_data=test_data.join(pd.get_dummies(test_data.ocean)).drop(['ocean'],axis=1)

# %%
test_data.rename(columns={'ocean': 'ocean_proximity'}, inplace=True)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4028     -118.56     34.18                39.0     7.506592        5.676754
# 17392    -120.45     34.96                21.0     7.660114        6.100319
# 11731    -120.81     39.02                30.0     6.693324        5.247024
# 12421    -116.23     33.72                32.0     8.513587        7.190676
# 1632     -122.17     37.87                38.0     7.140453        5.181784
# ...          ...       ...                 ...          ...             ...
# 12531    -121.50     38.57                44.0     7.226936        5.863631
# 13120    -121.27     38.31                17.0     7.043160        5.313206
# 20330    -119.03     34.25                25.0     8.115222        6.220590
# 6473     -118.07     34.09                40.0     7.465083        5.916202
# 887      -121.99     37.55                16.0     8.802071        7.649216
#
# ...

# %%
X_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4028     -118.56     34.18                39.0     7.506592        5.676754
# 17392    -120.45     34.96                21.0     7.660114        6.100319
# 11731    -120.81     39.02                30.0     6.693324        5.247024
# 12421    -116.23     33.72                32.0     8.513587        7.190676
# 1632     -122.17     37.87                38.0     7.140453        5.181784
# ...          ...       ...                 ...          ...             ...
# 12531    -121.50     38.57                44.0     7.226936        5.863631
# 13120    -121.27     38.31                17.0     7.043160        5.313206
# 20330    -119.03     34.25                25.0     8.115222        6.220590
# 6473     -118.07     34.09                40.0     7.465083        5.916202
# 887      -121.99     37.55                16.0     8.802071        7.649216
#
# ...

# %%
y_test
# Out:
# 4028     457300.0
# 17392    117600.0
# 11731    101000.0
# 12421     76900.0
# 1632     438000.0
#            ...
# 12531     87500.0
# 13120    151600.0
# 20330    340600.0
# 6473     198100.0
# 887      213800.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
X_test=test_data.drop(['median_house_value'],axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest=RandomForestRegressor()

# %%
forest.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
RandomForestRegressor().fit(X_test,y_test)
# Out:
# RandomForestRegressor()

# %%
# Assuming X_train and X_test are DataFrames
# Check if the columns are in the same order
if not all(X_test.columns == X_train.columns):
    # Reorder the columns in X_test to match the order in X_train
    X_test = X_test[X_train.columns]

# %%
# Assuming 'forest' is your model
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Check for additional columns in X_test
extra_columns = set(X_test.columns) - set(X_train.columns)
if extra_columns:
    # Drop the additional columns from X_test
    X_test = X_test.drop(columns=extra_columns)

# %%
forest.score(X_test,y_test)
# Out:
# 0.813994341855082

# %%
from sklearn.model_selection import GridSearchCV

# %%
params_grid = {
    "n_estimators": [3, 10, 30],
    "max_features": [2, 4, 6, 8]
}

grid_search = GridSearchCV(forest, params_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest=grid_search.best_estimator_

# %%
best_forest.score(X_test,y_test)
# Out:
# 0.8080728466396343
